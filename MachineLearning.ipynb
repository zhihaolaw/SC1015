# %% [markdown]
# <a href="https://colab.research.google.com/github/zhihaolaw/SC1015/blob/main/MachineLearning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import library
from google.colab import drive
drive.mount('/content/gdrive')
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
life_expectancy_dt = pd.read_csv('gdrive/My Drive/cleaned_life_expectancy_data.csv')

# %%
life_expectancy_dt.info()
df = pd.DataFrame(life_expectancy_dt)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 25 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Unnamed: 0                       2938 non-null   int64
#  1   COUNTRY                          2938 non-null   object
#  2   YEAR                             2938 non-null   int64
#  3   STATUS                           2938 non-null   object
#  4   LIFE_EXPECTANCY_                 2938 non-null   float64
#  5   ADULT_MORTALITY                  2938 non-null   float64
#  6   INFANT_DEATHS                    2938 non-null   float64
#  7   ALCOHOL                          2938 non-null   float64
#  8   PERCENTAGE_EXPENDITURE           2938 non-null   float64
#  9   HEPATITIS_B                      2938 non-null   float64
#  10  MEASLES_                         2938 non-null   float64
#  11  _BMI_                            2938 non-null   float64
# ...

# %% [markdown]
# # **Machine Learning Model**
#
# ---

# %% [markdown]
# ## **Linear Regression Model**

# %%
# Import essential models and functions from sklearn
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
#life_expectancy_dt, adult_mortality
lifeExpectancy = pd.DataFrame(life_expectancy_dt['LIFE_EXPECTANCY_'])  # Response
adultMortality = pd.DataFrame(life_expectancy_dt['ADULT_MORTALITY'])        # Predictor

# Split the Dataset into Train and Test
X_train, X_test, y_train, y_test = train_test_split(adultMortality, lifeExpectancy, test_size = 0.2)

# Linear Regression using Train Data
linreg = LinearRegression()         # create the linear regression object
linreg.fit(X_train, y_train)        # train the linear regression model

# Coefficients of the Linear Regression line
print('Intercept of Regression \t: b = ', linreg.intercept_)
print('Coefficients of Regression \t: a = ', linreg.coef_)
print()

# Predict Life Expectancy values corresponding to Adult Mortality
y_train_pred = linreg.predict(X_train)
y_test_pred = linreg.predict(X_test)

# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Explained Variance (R^2) \t:", linreg.score(X_train, y_train))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_train, y_train_pred))
print()

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", linreg.score(X_test, y_test))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_test, y_test_pred))
print()

# Plot the Predictions vs the True values
f, axes = plt.subplots(1, 2, figsize=(12, 12))
axes[0].scatter(y_train, y_train_pred, color = "blue")
axes[0].plot(y_train, y_train, color="red", linewidth = 1)
axes[0].set_xlabel("True values of the Response Variable (Train)")
axes[0].set_ylabel("Predicted values of the Response Variable (Train)")
axes[1].scatter(y_test, y_test_pred, color = "green")
axes[1].plot(y_test, y_test, color="red", linewidth = 1)
axes[1].set_xlabel("True values of the Response Variable (Test)")
axes[1].set_ylabel("Predicted values of the Response Variable (Test)")
plt.show()
# Out:
# Intercept of Regression 	: b =  [77.51538543]
# Coefficients of Regression 	: a =  [[-0.05386411]]
#
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.36059955714533365
# Mean Squared Error (MSE) 	: 56.158329484365716
#
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.3863033595230615
# Mean Squared Error (MSE) 	: 52.58784569731498

# %%
#life_expectancy_dt, income
lifeExpectancy = pd.DataFrame(life_expectancy_dt['LIFE_EXPECTANCY_'])  # Response
incomeComposition = pd.DataFrame(life_expectancy_dt['INCOME_COMPOSITION_OF_RESOURCES'])        # Predictor

# Split the Dataset into Train and Test
X_train, X_test, y_train, y_test = train_test_split(incomeComposition, lifeExpectancy, test_size = 0.2)

# Linear Regression using Train Data
linreg = LinearRegression()         # create the linear regression object
linreg.fit(X_train, y_train)        # train the linear regression model

# Coefficients of the Linear Regression line
print('Intercept of Regression \t: b = ', linreg.intercept_)
print('Coefficients of Regression \t: a = ', linreg.coef_)
print()

# Predict Life Expectancy values corresponding to Income
y_train_pred = linreg.predict(X_train)
y_test_pred = linreg.predict(X_test)

# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Explained Variance (R^2) \t:", linreg.score(X_train, y_train))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_train, y_train_pred))
print()

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", linreg.score(X_test, y_test))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_test, y_test_pred))
print()

# Plot the Predictions vs the True values
f, axes = plt.subplots(1, 2, figsize=(12, 12))
axes[0].scatter(y_train, y_train_pred, color = "blue")
axes[0].plot(y_train, y_train, color="red", linewidth = 1)
axes[0].set_xlabel("True values of the Response Variable (Train)")
axes[0].set_ylabel("Predicted values of the Response Variable (Train)")
axes[1].scatter(y_test, y_test_pred, color = "green")
axes[1].plot(y_test, y_test, color="red", linewidth = 1)
axes[1].set_xlabel("True values of the Response Variable (Test)")
axes[1].set_ylabel("Predicted values of the Response Variable (Test)")
plt.show()
# Out:
# Intercept of Regression 	: b =  [36.42564456]
# Coefficients of Regression 	: a =  [[50.16741521]]
#
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.7467105226848848
# Mean Squared Error (MSE) 	: 22.522488755138127
#
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.7350778693748294
# Mean Squared Error (MSE) 	: 21.62819226883425

# %%
#life_expectancy_dt, schooling
lifeExpectancy = pd.DataFrame(life_expectancy_dt['LIFE_EXPECTANCY_'])  # Response
schooling = pd.DataFrame(life_expectancy_dt['SCHOOLING'])        # Predictor

# Split the Dataset into Train and Test
X_train, X_test, y_train, y_test = train_test_split(schooling, lifeExpectancy, test_size = 0.2)

# Linear Regression using Train Data
linreg = LinearRegression()         # create the linear regression object
linreg.fit(X_train, y_train)        # train the linear regression model

# Coefficients of the Linear Regression line
print('Intercept of Regression \t: b = ', linreg.intercept_)
print('Coefficients of Regression \t: a = ', linreg.coef_)
print()

# Predict Life Expectancy values corresponding to Schooling
y_train_pred = linreg.predict(X_train)
y_test_pred = linreg.predict(X_test)

# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Explained Variance (R^2) \t:", linreg.score(X_train, y_train))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_train, y_train_pred))
print()

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", linreg.score(X_test, y_test))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_test, y_test_pred))
print()

# Plot the Predictions vs the True values
f, axes = plt.subplots(1, 2, figsize=(12, 12))
axes[0].scatter(y_train, y_train_pred, color = "blue")
axes[0].plot(y_train, y_train, color="red", linewidth = 1)
axes[0].set_xlabel("True values of the Response Variable (Train)")
axes[0].set_ylabel("Predicted values of the Response Variable (Train)")
axes[1].scatter(y_test, y_test_pred, color = "green")
axes[1].plot(y_test, y_test, color="red", linewidth = 1)
axes[1].set_xlabel("True values of the Response Variable (Test)")
axes[1].set_ylabel("Predicted values of the Response Variable (Test)")
plt.show()
# Out:
# Intercept of Regression 	: b =  [41.08529591]
# Coefficients of Regression 	: a =  [[2.32197841]]
#
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.607423118984623
# Mean Squared Error (MSE) 	: 35.14265044472881
#
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.5589493536215959
# Mean Squared Error (MSE) 	: 34.85248393063073

# %% [markdown]
# In terms of the Linear Regression Model, Income is the best in terms of the Goodness of Fit as it has the best Explained Variance (R^2) of around 0.7. Income is also best in terms of Test Accuracy, it has also the best(lowest) MSE among the 3. Income is the best among the 3 in this case.

# %% [markdown]
# ## **Support Vector Regression Model**

# %%
# Import essential models and functions from sklearn
from sklearn.svm import SVR
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import explained_variance_score
import matplotlib.pyplot as plt

# %%
#life_expectancy_dt, adult_mortality
lifeExpectancy = pd.DataFrame(life_expectancy_dt['LIFE_EXPECTANCY_'])  # Response
adultMortality = pd.DataFrame(life_expectancy_dt['ADULT_MORTALITY'])        # Predictor

# Split the Dataset into Train and Test
X_train, X_test, y_train, y_test = train_test_split(adultMortality, lifeExpectancy, test_size = 0.2)

# Initalise the SVR model
model = SVR(kernel='linear')


# Train SVR model
model.fit(X_train, y_train.values.ravel())

# Predict Life Expectancy values corresponding to Adult Mortality
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

# MSE
trainMse = mean_squared_error(y_train, y_train_pred)
testMse = mean_squared_error(y_test, y_test_pred)

# Explain Variance
trainR2 = explained_variance_score(y_train, y_train_pred)
testR2 = explained_variance_score(y_test, y_test_pred)

# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Explained Variance (R^2) \t:", trainR2)
print("Mean Squared Error (MSE) \t:", trainMse)
print()

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", testR2)
print("Mean Squared Error (MSE) \t:", testMse)
print()

# Plot the Predictions vs the True values
f, axes = plt.subplots(1, 2, figsize=(12, 12))
axes[0].scatter(y_train, y_train_pred, color="blue")
axes[0].plot(y_train, y_train, color="red", linewidth=1)
axes[0].set_xlabel("True values of the Response Variable (Train)")
axes[0].set_ylabel("Predicted values of the Response Variable (Train)")
axes[1].scatter(y_test, y_test_pred, color="green")
axes[1].plot(y_test, y_test, color="red", linewidth=1)
axes[1].set_xlabel("True values of the Response Variable (Test)")
axes[1].set_ylabel("Predicted values of the Response Variable (Test)")
plt.show()
# Out:
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.35058808942470576
# Mean Squared Error (MSE) 	: 61.355577873985226
#
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.25018622144408076
# Mean Squared Error (MSE) 	: 70.37236002692431

# %%
#life_expectancy_dt, income
lifeExpectancy = pd.DataFrame(life_expectancy_dt['LIFE_EXPECTANCY_'])  # Response
income = pd.DataFrame(life_expectancy_dt['INCOME_COMPOSITION_OF_RESOURCES'])        # Predictor

# Split the Dataset into Train and Test
X_train, X_test, y_train, y_test = train_test_split(income, lifeExpectancy, test_size = 0.2)

# Initalise the SVR model
model = SVR(kernel='linear')


# Train SVR model
model.fit(X_train, y_train.values.ravel())

# Predict Life Expectancy values corresponding to Income
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

# MSE
trainMse = mean_squared_error(y_train, y_train_pred)
testMse = mean_squared_error(y_test, y_test_pred)

# Explain Variance
trainR2 = explained_variance_score(y_train, y_train_pred)
testR2 = explained_variance_score(y_test, y_test_pred)

# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Explained Variance (R^2) \t:", trainR2)
print("Mean Squared Error (MSE) \t:", trainMse)
print()

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", testR2)
print("Mean Squared Error (MSE) \t:", testMse)
print()

# Plot the Predictions vs the True values
f, axes = plt.subplots(1, 2, figsize=(12, 12))
axes[0].scatter(y_train, y_train_pred, color="blue")
axes[0].plot(y_train, y_train, color="red", linewidth=1)
axes[0].set_xlabel("True values of the Response Variable (Train)")
axes[0].set_ylabel("Predicted values of the Response Variable (Train)")
axes[1].scatter(y_test, y_test_pred, color="green")
axes[1].plot(y_test, y_test, color="red", linewidth=1)
axes[1].set_xlabel("True values of the Response Variable (Test)")
axes[1].set_ylabel("Predicted values of the Response Variable (Test)")
plt.show()
# Out:
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.7311152328196369
# Mean Squared Error (MSE) 	: 23.531883953800214
#
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.7491037356003429
# Mean Squared Error (MSE) 	: 23.603128969289664

# %%
#life_expectancy_dt, schooling
lifeExpectancy = pd.DataFrame(life_expectancy_dt['LIFE_EXPECTANCY_'])  # Response
schooling = pd.DataFrame(life_expectancy_dt['SCHOOLING'])        # Predictor

# Split the Dataset into Train and Test
X_train, X_test, y_train, y_test = train_test_split(schooling, lifeExpectancy, test_size = 0.2)

# Initalise the SVR model
model = SVR(kernel='linear')


# Train SVR model
model.fit(X_train, y_train.values.ravel())

# Predict Life Expectancy values corresponding to Schooling
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

# MSE
trainMse = mean_squared_error(y_train, y_train_pred)
testMse = mean_squared_error(y_test, y_test_pred)

# Explained Variance
trainR2 = explained_variance_score(y_train, y_train_pred)
testR2 = explained_variance_score(y_test, y_test_pred)

# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Explained Variance (R^2) \t:", trainR2)
print("Mean Squared Error (MSE) \t:", trainMse)
print()

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", testR2)
print("Mean Squared Error (MSE) \t:", testMse)
print()

# Plot the Predictions vs the True values
f, axes = plt.subplots(1, 2, figsize=(12, 12))
axes[0].scatter(y_train, y_train_pred, color="blue")
axes[0].plot(y_train, y_train, color="red", linewidth=1)
axes[0].set_xlabel("True values of the Response Variable (Train)")
axes[0].set_ylabel("Predicted values of the Response Variable (Train)")
axes[1].scatter(y_test, y_test_pred, color="green")
axes[1].plot(y_test, y_test, color="red", linewidth=1)
axes[1].set_xlabel("True values of the Response Variable (Test)")
axes[1].set_ylabel("Predicted values of the Response Variable (Test)")
plt.show()
# Out:
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.5960846817021181
# Mean Squared Error (MSE) 	: 36.621059098105704
#
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.6067278437580865
# Mean Squared Error (MSE) 	: 32.98432821811933

# %% [markdown]
# In terms of the Support Vector Regressor Model, Income is the best in terms of the Goodness of Fit as it has the best Explained Variance (R^2) of around 0.7. Income is also best in terms of Test Accuracy, it has also the best(lowest) MSE among the 3. Income is the best among the 3 in this case.

# %% [markdown]
# ## **Random Forest Regression Model**
#
# ---

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import accuracy_score
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# %%
#life_expectancy_dt, schooling
lifeExpectancy = pd.DataFrame(life_expectancy_dt['LIFE_EXPECTANCY_'])  # Response
schooling = pd.DataFrame(life_expectancy_dt['SCHOOLING'])        # Predictor

#Split the Dataset into Train and Test
X_train, X_test, y_train, y_test = train_test_split(schooling, lifeExpectancy, test_size = 0.2, random_state=42)

#Creation of Random Forest Regressor
randomForestRegressor = RandomForestRegressor(n_estimators=100, max_depth=4, random_state=42)

#Ravel y_train to avoid warnings
randomForestRegressor.fit(X_train, y_train.values.ravel())

# Predictions
trainPredictions = randomForestRegressor.predict(X_train)
testPredictions = randomForestRegressor.predict(X_test)

# MSE
trainMse = mean_squared_error(y_train, trainPredictions)
testMse = mean_squared_error(y_test, testPredictions)

# Explained Variance
trainR2 = explained_variance_score(y_train, trainPredictions)
testR2 = explained_variance_score(y_test, testPredictions)

# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Explained Variance (R^2) \t:", trainR2)
print("Mean Squared Error (MSE) \t:", trainMse)
print()

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", testR2)
print("Mean Squared Error (MSE) \t:", testMse)
print()
# Out:
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.6397998424334491
# Mean Squared Error (MSE) 	: 31.777154362490673
#
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.6738192502807393
# Mean Squared Error (MSE) 	: 27.56899598770537

# %%
from sklearn import tree
import matplotlib.pyplot as plt

# Choose a tree from the forest
tree_forest = randomForestRegressor.estimators_[0]

# Plot the tree
plt.figure(figsize=(20, 10))
tree.plot_tree(tree_forest, feature_names=schooling.columns, filled=True)
plt.show()

# %%
#life_expectancy_dt, income
lifeExpectancy = pd.DataFrame(life_expectancy_dt['LIFE_EXPECTANCY_'])  # Response
income = pd.DataFrame(life_expectancy_dt['INCOME_COMPOSITION_OF_RESOURCES'])        # Predictor

#Split the Dataset into Train and Test
X_train, X_test, y_train, y_test = train_test_split(income, lifeExpectancy, test_size = 0.2, random_state=42)

#Creation of Random Forest Regressor
randomForestRegressor = RandomForestRegressor(n_estimators=100, max_depth=4, random_state=42)

#Ravel y_train to avoid warnings
randomForestRegressor.fit(X_train, y_train.values.ravel())

# Predictions
trainPredictions = randomForestRegressor.predict(X_train)
testPredictions = randomForestRegressor.predict(X_test)

# MSE
trainMse = mean_squared_error(y_train, trainPredictions)
testMse = mean_squared_error(y_test, testPredictions)

# Explained Variance
trainR2 = explained_variance_score(y_train, trainPredictions)
testR2 = explained_variance_score(y_test, testPredictions)

# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Explained Variance (R^2) \t:", trainR2)
print("Mean Squared Error (MSE) \t:", trainMse)
print()

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", testR2)
print("Mean Squared Error (MSE) \t:", testMse)
print()
# Out:
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.7645590372485406
# Mean Squared Error (MSE) 	: 20.770804421082417
#
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.7712698797861876
# Mean Squared Error (MSE) 	: 19.349049444338327

# %%
from sklearn import tree
import matplotlib.pyplot as plt

# Choose a tree from the forest
tree_forest = randomForestRegressor.estimators_[0]

# Plot the tree
plt.figure(figsize=(20, 10))
tree.plot_tree(tree_forest, feature_names=schooling.columns, filled=True)
plt.show()

# %%
#life_expectancy_dt, adult_mortality
lifeExpectancy = pd.DataFrame(life_expectancy_dt['LIFE_EXPECTANCY_'])  # Response
adultMortality = pd.DataFrame(life_expectancy_dt['ADULT_MORTALITY'])        # Predictor

#Split the Dataset into Train and Test
X_train, X_test, y_train, y_test = train_test_split(adultMortality, lifeExpectancy, test_size = 0.2, random_state=42)

#Creation of Random Forest Regressor
randomForestRegressor = RandomForestRegressor(n_estimators=100, max_depth=4, random_state=42)

#Ravel y_train to avoid warnings
randomForestRegressor.fit(X_train, y_train.values.ravel())

# Predictions
trainPredictions = randomForestRegressor.predict(X_train)
testPredictions = randomForestRegressor.predict(X_test)

# MSE
trainMse = mean_squared_error(y_train, trainPredictions)
testMse = mean_squared_error(y_test, testPredictions)

# Explained Variance
trainR2 = explained_variance_score(y_train, trainPredictions)
testR2 = explained_variance_score(y_test, testPredictions)

# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Explained Variance (R^2) \t:", trainR2)
print("Mean Squared Error (MSE) \t:", trainMse)
print()

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", testR2)
print("Mean Squared Error (MSE) \t:", testMse)
print()
# Out:
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.7881670117199295
# Mean Squared Error (MSE) 	: 18.68805080969951
#
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.8205346431161598
# Mean Squared Error (MSE) 	: 15.169093750809058

# %%
from sklearn import tree
import matplotlib.pyplot as plt

# Choose a tree from the forest
tree_forest = randomForestRegressor.estimators_[0]

# Plot the tree
plt.figure(figsize=(20, 10))
tree.plot_tree(tree_forest, feature_names=schooling.columns, filled=True)
plt.show()

# %% [markdown]
# In terms of Random Forest Regressor Model, Adult Mortality is the best in terms of the Goodness of Fit as it has the best Explained Variance (R^2) of around 0.8. Adult Mortality is also best in terms of Test Accuracy, it has also the best(lowest) MSE among the 3. Adult Mortality is the best among the 3 in this case.

# %% [markdown]
# After experimenting with these 3 models, we observed variations in feature importance across different regression models. However, for linear regression and support vector regression (SVR), income was the most influential variable, while for the random forest regressor, adult mortality was the most significant.

# %% [markdown]
# ## **K-Means Clustering Model**

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
#import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.datasets import make_blobs

# %%
# Kmeans clustering(second method)
clusteringColumns2 = ['GDP', 'ADULT_MORTALITY', 'INFANT_DEATHS', 'ALCOHOL', 'MEASLES_', 'PERCENTAGE_EXPENDITURE', 'POLIO', 'DIPHTHERIA_', '_HIV/AIDS', 'POPULATION', 'INCOME_COMPOSITION_OF_RESOURCES', 'SCHOOLING', '_THINNESS__1_19_YEARS', '_THINNESS_5_9_YEARS']

clusteringColumns2 , true_labels = make_blobs(n_samples=2938, centers=3, cluster_std=2.75, random_state=42)

# Standarizing the numerical columns
scaler = StandardScaler()
columnstobeScaled = scaler.fit_transform(clusteringColumns2)

# Kmeans clustering
kmeans = KMeans(init="random", n_clusters=3, n_init=10, max_iter=300, random_state=42)
kmeans.fit(columnstobeScaled)

# Lowest SSE value
print(kmeans.inertia_)

# Locations
print(kmeans.cluster_centers_)

# Iterations
print(kmeans.n_iter_)

kmeans.labels_[:5]
# Out:
# 1107.4410581670663
# [[-0.98623913 -1.16911837]
#  [ 1.15165434  0.092294  ]
#  [-0.17419247  1.07947505]]
# 7
# array([1, 2, 1, 2, 2], dtype=int32)

# %% [markdown]
# The lowest SSE value is around 1107. This is basically the sum of squared distances of samples to their cluster center. The lower the SSE value, the betteer the cluster is defined.
#
# Cluster Centers:
# Cluster 1: [ -0.98623913 -1.16911837],
# Cluster 2: [1.15165434  0.092294],
# Cluster 3: [-0.17419247  1.07947505]
#
#
# The output array([1, 2, 1, 2, 2], dtype=int32) shows the labels of the first 5 data points after clustering.

# %%
kmeans_kwargs = { "init" : "random", "n_init" : 10, "max_iter" : 300, "random_state" : 42,}

#list for the SSE values
sseValues = []
for k in range(1,11):
  kmeans = KMeans(n_clusters = k, **kmeans_kwargs)
  kmeans.fit(columnstobeScaled)
  sseValues.append(kmeans.inertia_)

plt.plot(range(1,11), sseValues)
plt.xlabel("Clusters")
plt.ylabel("SSE Values")
plt.show()

# %% [markdown]
# The Elbow Method helped us to determine the optimal number of clusters to group countries with similar life expectancy patterns. In this method, we cluster countries based on various healthcare metrics and by plotting the SSE against the number of clusters. By doing so, We were able to reveal distinct groups of countries with similar healthcare profiles. To determine number of clusters, need find the elbow point, in this case its 3

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
#import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

#life_expectancy_dt
#columns for clustering(first method)
clusteringColumns = ['GDP', 'ADULT_MORTALITY', 'INFANT_DEATHS', 'ALCOHOL', 'MEASLES_', 'PERCENTAGE_EXPENDITURE', 'POLIO', 'DIPHTHERIA_', '_HIV/AIDS', 'POPULATION', 'INCOME_COMPOSITION_OF_RESOURCES', 'SCHOOLING', '_THINNESS__1_19_YEARS', '_THINNESS_5_9_YEARS']

#standarizing the numerical columns
scaler = StandardScaler()
columnstobeScaled = life_expectancy_dt[clusteringColumns].copy()
columnstobeScaled = scaler.fit_transform(columnstobeScaled)

#kmean clustering
kmeans = KMeans(n_clusters=3, random_state=42) #3 clusters used based on the output of the previous
kmeans.fit(columnstobeScaled)
clusterLabels = kmeans.labels_

df['Cluster'] = clusterLabels

pca = PCA(n_components=2)
X_pca = pca.fit_transform(columnstobeScaled)

plt.figure(figsize=(8,8))
plt.title('K-means Clustering for Maximizing Life Expectancy')
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=clusterLabels, cmap='inferno')
plt.xlabel('Healthcare Metric')
plt.ylabel('Factors')
plt.colorbar(label='Cluster')
plt.grid(True)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# We used the Principal Component Analysis (PCA) to reduce the dimensionality of the data. We transformed the original healthcare metrics into two principal components. By doing so, we can visually inspect how well the clustering algorithm separates countries with different healthcare profiles.

# %% [markdown]
# ## **Decision Tree Classifier Model**

# %%
# Import Decision Tree Classifier model from Scikit-Learn
from sklearn.tree import DecisionTreeClassifier
# Plot the trained Decision Tree
from sklearn.tree import plot_tree
#from sklearn.impute import SimpleImputer

# Import essential models and functions from sklearn
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

# %%
# Define the features and the target
features = ['INCOME_COMPOSITION_OF_RESOURCES', 'ADULT_MORTALITY', 'SCHOOLING']
target = 'LIFESPAN'

#life_expectancy_dt[features] = imputer.fit_transform(life_expectancy_dt[features])

# Preparing the data for the model
X = life_expectancy_dt[features]
y = life_expectancy_dt[target]

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# Initialize the Decision Tree Classifier
tree_classifier = DecisionTreeClassifier(max_depth=4)

# Train the classifier
tree_classifier.fit(X_train, y_train)

# Plot the decision tree
plt.figure(figsize=(40,20))
tree_plot = plot_tree(tree_classifier,
                      feature_names=features,
                      class_names=tree_classifier.classes_,
                      filled=True,
                      rounded=True,
                      fontsize=12)
plt.show()

# %% [markdown]
# Our team decided to implement the classification tree to compare the importance of the different variables. We mainly compare the 3 variables, INCOME_COMPOSITION_OF_RESOURCES, ADULT_MORTALITY and SCHOOLING

# %% [markdown]
# *INCOME_COMPOSITION_OF_RESOURCES* was the first predictor variable to appear at the top of the classification tree. Hence it is deemed as the most important variable in predicting the lifespan.
#
# Going down the decision tree, *ADULT_MORTALITY* was the next variable used to split the data set at the 2nd level of the tree.
#
# *SCHOOLING* was the 3rd variable to be used to split the tree at the 4th level.

# %% [markdown]
# Order of importance
# 1. INCOME_COMPOSITION_OF_RESOURCES
# 2. ADULT_MORTALITY
# 3. SCHOOLING

# %%
# declaration of variables for the following classification trees
lifespan = pd.DataFrame(life_expectancy_dt['LIFESPAN'])                       # Response
income = pd.DataFrame(life_expectancy_dt['INCOME_COMPOSITION_OF_RESOURCES'])  # Predictor 1
mortality = pd.DataFrame(life_expectancy_dt['ADULT_MORTALITY'])               # Predictor 2
school = pd.DataFrame(life_expectancy_dt['SCHOOLING'])                        # Predictor 3

# %%
# Split the Dataset into Train and Test
income_train, income_test, lifespan_train, lifespan_test = train_test_split(income, lifespan, test_size = 0.2)

# Create a Decision Tree Classifier object
dectree = DecisionTreeClassifier(max_depth = 3)

# Train the Decision Tree Classifier model
dectree.fit(income_train, lifespan_train)

f = plt.figure(figsize=(12,12))
plot_tree(dectree, filled=True, rounded=True,
          feature_names=["Income"],
          class_names=["Low","High"])
# Out:
# [Text(0.5, 0.875, 'Income <= 0.652\ngini = 0.495\nsamples = 2350\nvalue = [1287, 1063]\nclass = Low'),
#  Text(0.25, 0.625, 'Income <= 0.56\ngini = 0.237\nsamples = 1075\nvalue = [148, 927]\nclass = High'),
#  Text(0.125, 0.375, 'Income <= 0.544\ngini = 0.012\nsamples = 672\nvalue = [4, 668]\nclass = High'),
#  Text(0.0625, 0.125, 'gini = 0.0\nsamples = 632\nvalue = [0, 632]\nclass = High'),
#  Text(0.1875, 0.125, 'gini = 0.18\nsamples = 40\nvalue = [4, 36]\nclass = High'),
#  Text(0.375, 0.375, 'Income <= 0.639\ngini = 0.459\nsamples = 403\nvalue = [144, 259]\nclass = High'),
#  Text(0.3125, 0.125, 'gini = 0.448\nsamples = 354\nvalue = [120, 234]\nclass = High'),
#  Text(0.4375, 0.125, 'gini = 0.5\nsamples = 49\nvalue = [24, 25]\nclass = High'),
#  Text(0.75, 0.625, 'Income <= 0.709\ngini = 0.191\nsamples = 1275\nvalue = [1139, 136]\nclass = Low'),
#  Text(0.625, 0.375, 'Income <= 0.654\ngini = 0.427\nsamples = 288\nvalue = [199, 89]\nclass = Low'),
# ...

# %%
# Create a Decision Tree Classifier object
dectree = DecisionTreeClassifier(max_depth = 3)

# Train the Decision Tree Classifier model
dectree.fit(income_test, lifespan_test)

f = plt.figure(figsize=(12,12))
plot_tree(dectree, filled=True, rounded=True,
          feature_names=["Income"],
          class_names=["Low","High"])
# Out:
# [Text(0.5, 0.875, 'Income <= 0.64\ngini = 0.484\nsamples = 588\nvalue = [347, 241]\nclass = Low'),
#  Text(0.25, 0.625, 'Income <= 0.568\ngini = 0.263\nsamples = 244\nvalue = [38, 206]\nclass = High'),
#  Text(0.125, 0.375, 'Income <= 0.56\ngini = 0.013\nsamples = 149\nvalue = [1, 148]\nclass = High'),
#  Text(0.0625, 0.125, 'gini = 0.0\nsamples = 143\nvalue = [0, 143]\nclass = High'),
#  Text(0.1875, 0.125, 'gini = 0.278\nsamples = 6\nvalue = [1, 5]\nclass = High'),
#  Text(0.375, 0.375, 'Income <= 0.579\ngini = 0.476\nsamples = 95\nvalue = [37, 58]\nclass = High'),
#  Text(0.3125, 0.125, 'gini = 0.219\nsamples = 8\nvalue = [7, 1]\nclass = Low'),
#  Text(0.4375, 0.125, 'gini = 0.452\nsamples = 87\nvalue = [30, 57]\nclass = High'),
#  Text(0.75, 0.625, 'Income <= 0.72\ngini = 0.183\nsamples = 344\nvalue = [309, 35]\nclass = Low'),
#  Text(0.625, 0.375, 'Income <= 0.719\ngini = 0.381\nsamples = 117\nvalue = [87, 30]\nclass = Low'),
# ...

# %%
# Predict Response corresponding to Predictors
lifespan_train_pred_1 = dectree.predict(income_train)
lifespan_test_pred_1 = dectree.predict(income_test)

# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Classification Accuracy \t:", dectree.score(income_train, lifespan_train))
print()

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Classification Accuracy \t:", dectree.score(income_test, lifespan_test))
print()

# Plot the Confusion Matrix for Train and Test
f, axes = plt.subplots(1, 2, figsize=(12, 4))
cm_train_1 = confusion_matrix(lifespan_train, lifespan_train_pred_1)
sns.heatmap(cm_train_1,
           annot = True, fmt=".0f", annot_kws={"size": 18}, ax = axes[0])
cm_test_1 = confusion_matrix(lifespan_test, lifespan_test_pred_1)
sns.heatmap(cm_test_1,
           annot = True, fmt=".0f", annot_kws={"size": 18}, ax = axes[1])

#Print the TPR and FPR for train set
print ()
FP_tr_1 = cm_train_1[0][1]
FN_tr_1 = cm_train_1[1][0]
TP_tr_1 = cm_train_1[1][1]
TN_tr_1 = cm_train_1[0][0]
print("For train set")
print("The True Positive Rate of trian set for this model \t:", TP_tr_1/(FN_tr_1 + TP_tr_1))
print("The False Positive Rate of train set for this model \t:", FP_tr_1/(TN_tr_1 + FP_tr_1))


#Print the TPR and FPR for test set
print()
FP_tt_1 = cm_test_1[0][1]
FN_tt_1 = cm_test_1[1][0]
TP_tt_1 = cm_test_1[1][1]
TN_tt_1 = cm_test_1[0][0]
print("For test set")
print("The True Positive Rate of test set for this model \t:", TP_tt_1/(FN_tt_1 + TP_tt_1))
print("The False Positive Rate of test set for this model \t:", FP_tt_1/(TN_tt_1 + FP_tt_1))
# Out:
# Goodness of Fit of Model 	Train Dataset
# Classification Accuracy 	: 0.8710638297872341
#
# Goodness of Fit of Model 	Test Dataset
# Classification Accuracy 	: 0.8877551020408163
#
#
# For train set
# The True Positive Rate of trian set for this model 	: 0.8344308560677328
# The False Positive Rate of train set for this model 	: 0.09867909867909867
#
# For test set
# The True Positive Rate of test set for this model 	: 0.8547717842323651
# The False Positive Rate of test set for this model 	: 0.0893371757925072

# %% [markdown]
# *INCOME_COMPOSITION_OF_RESOURCES*
#
# Train Accuracy: 0.8711, TPR: 0.8344, FPR: 0.0987
#
# Test Accuracy: 0.8878, TPR: 0.8548, FPR: 0.0893
#
# The model shows good performance on both the training and testing sets, with high accuracy scores (train with 0.8711 and test with 0.8878).
#
# The true positive rate (TPR) is relatively high with a value of 0.8344 on the training set and 0.8548 on the test set. This indicates that the models correctly identifies a significant portion of positive cases related to income composition of resources.
#
# The false positive rate (FPR) is relatively low as well, with the training set having a value of only 0.0987 and the test set having a value of 0.0893. This means that the model has a low tendency to incorrectly classify negative cases as positive. Models with a high FPR value may indicate overfitting or other issues with is not the case for these models.

# %%
# Create a Decision Tree Classifier object
dectree = DecisionTreeClassifier(max_depth = 4)

# Train the Decision Tree Classifier model
dectree.fit(income_train, lifespan_train)

f = plt.figure(figsize=(16,16))
plot_tree(dectree, filled=True, rounded=True,
          feature_names=["Income"],
          class_names=["Low","High"])
# Out:
# [Text(0.46, 0.9, 'Income <= 0.652\ngini = 0.495\nsamples = 2350\nvalue = [1287, 1063]\nclass = Low'),
#  Text(0.22, 0.7, 'Income <= 0.56\ngini = 0.237\nsamples = 1075\nvalue = [148, 927]\nclass = High'),
#  Text(0.08, 0.5, 'Income <= 0.544\ngini = 0.012\nsamples = 672\nvalue = [4, 668]\nclass = High'),
#  Text(0.04, 0.3, 'gini = 0.0\nsamples = 632\nvalue = [0, 632]\nclass = High'),
#  Text(0.12, 0.3, 'Income <= 0.546\ngini = 0.18\nsamples = 40\nvalue = [4, 36]\nclass = High'),
#  Text(0.08, 0.1, 'gini = 0.444\nsamples = 3\nvalue = [1, 2]\nclass = High'),
#  Text(0.16, 0.1, 'gini = 0.149\nsamples = 37\nvalue = [3, 34]\nclass = High'),
#  Text(0.36, 0.5, 'Income <= 0.639\ngini = 0.459\nsamples = 403\nvalue = [144, 259]\nclass = High'),
#  Text(0.28, 0.3, 'Income <= 0.603\ngini = 0.448\nsamples = 354\nvalue = [120, 234]\nclass = High'),
#  Text(0.24, 0.1, 'gini = 0.483\nsamples = 110\nvalue = [45, 65]\nclass = High'),
# ...

# %%
# Split the Dataset into Train and Test
mortality_train, mortality_test, lifespan_train, lifespan_test = train_test_split(mortality, lifespan, test_size = 0.2)

# Create a Decision Tree Classifier object
dectree = DecisionTreeClassifier(max_depth = 3)

# Train the Decision Tree Classifier model
dectree.fit(mortality_train, lifespan_train)

f = plt.figure(figsize=(12,12))
plot_tree(dectree, filled=True, rounded=True,
          feature_names=["Adult_Mortality"],
          class_names=["Low","High"])
# Out:
# [Text(0.5, 0.875, 'Adult_Mortality <= 163.5\ngini = 0.493\nsamples = 2350\nvalue = [1315, 1035]\nclass = Low'),
#  Text(0.25, 0.625, 'Adult_Mortality <= 53.5\ngini = 0.266\nsamples = 1356\nvalue = [1142, 214]\nclass = Low'),
#  Text(0.125, 0.375, 'Adult_Mortality <= 20.0\ngini = 0.486\nsamples = 417\nvalue = [243, 174]\nclass = Low'),
#  Text(0.0625, 0.125, 'gini = 0.193\nsamples = 249\nvalue = [222, 27]\nclass = Low'),
#  Text(0.1875, 0.125, 'gini = 0.219\nsamples = 168\nvalue = [21, 147]\nclass = High'),
#  Text(0.375, 0.375, 'Adult_Mortality <= 150.0\ngini = 0.082\nsamples = 939\nvalue = [899, 40]\nclass = Low'),
#  Text(0.3125, 0.125, 'gini = 0.043\nsamples = 826\nvalue = [808, 18]\nclass = Low'),
#  Text(0.4375, 0.125, 'gini = 0.314\nsamples = 113\nvalue = [91, 22]\nclass = Low'),
#  Text(0.75, 0.625, 'Adult_Mortality <= 211.5\ngini = 0.288\nsamples = 994\nvalue = [173, 821]\nclass = High'),
# ...

# %%
# Create a Decision Tree Classifier object
dectree = DecisionTreeClassifier(max_depth = 3)

# Train the Decision Tree Classifier model
dectree.fit(mortality_test, lifespan_test)

f = plt.figure(figsize=(12,12))
plot_tree(dectree, filled=True, rounded=True,
          feature_names=["Adult_Mortality"],
          class_names=["Low","High"])
# Out:
# [Text(0.5, 0.875, 'Adult_Mortality <= 161.5\ngini = 0.496\nsamples = 588\nvalue = [319, 269]\nclass = Low'),
#  Text(0.25, 0.625, 'Adult_Mortality <= 49.5\ngini = 0.273\nsamples = 337\nvalue = [282, 55]\nclass = Low'),
#  Text(0.125, 0.375, 'Adult_Mortality <= 20.0\ngini = 0.5\nsamples = 101\nvalue = [50, 51]\nclass = High'),
#  Text(0.0625, 0.125, 'gini = 0.245\nsamples = 56\nvalue = [48, 8]\nclass = Low'),
#  Text(0.1875, 0.125, 'gini = 0.085\nsamples = 45\nvalue = [2, 43]\nclass = High'),
#  Text(0.375, 0.375, 'Adult_Mortality <= 148.5\ngini = 0.033\nsamples = 236\nvalue = [232, 4]\nclass = Low'),
#  Text(0.3125, 0.125, 'gini = 0.0\nsamples = 207\nvalue = [207, 0]\nclass = Low'),
#  Text(0.4375, 0.125, 'gini = 0.238\nsamples = 29\nvalue = [25, 4]\nclass = Low'),
#  Text(0.75, 0.625, 'Adult_Mortality <= 205.0\ngini = 0.251\nsamples = 251\nvalue = [37, 214]\nclass = High'),
# ...

# %%
# Predict Response corresponding to Predictors
lifespan_train_pred_2 = dectree.predict(mortality_train)
lifespan_test_pred_2 = dectree.predict(mortality_test)

# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Classification Accuracy \t:", dectree.score(mortality_train, lifespan_train))
print()

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Classification Accuracy \t:", dectree.score(mortality_test, lifespan_test))
print()

# Plot the Confusion Matrix for Train and Test
f, axes = plt.subplots(1, 2, figsize=(12, 4))
cm_train_2 = confusion_matrix(lifespan_train, lifespan_train_pred_2)
sns.heatmap(cm_train_2,
           annot = True, fmt=".0f", annot_kws={"size": 18}, ax = axes[0])
cm_test_2 = confusion_matrix(lifespan_test, lifespan_test_pred_2)
sns.heatmap(cm_test_2,
           annot = True, fmt=".0f", annot_kws={"size": 18}, ax = axes[1])

#Print the TPR and FPR for train set
print ()
FP_tr_2 = cm_train_2[0][1]
FN_tr_2 = cm_train_2[1][0]
TP_tr_2 = cm_train_2[1][1]
TN_tr_2 = cm_train_2[0][0]
print("For train set")
print("The True Positive Rate of trian set for this model \t:", TP_tr_2/(FN_tr_2 + TP_tr_2))
print("The False Positive Rate of train set for this model \t:", FP_tr_2/(TN_tr_2 + FP_tr_2))


#Print the TPR and FPR for test set
print()
FP_tt_2 = cm_test_2[0][1]
FN_tt_2 = cm_test_2[1][0]
TP_tt_2 = cm_test_2[1][1]
TN_tt_2 = cm_test_2[0][0]
print("For test set")
print("The True Positive Rate of test set for this model \t:", TP_tt_2/(FN_tt_2 + TP_tt_2))
print("The False Positive Rate of test set for this model \t:", FP_tt_2/(TN_tt_2 + FP_tt_2))
# Out:
# Goodness of Fit of Model 	Train Dataset
# Classification Accuracy 	: 0.8834042553191489
#
# Goodness of Fit of Model 	Test Dataset
# Classification Accuracy 	: 0.9132653061224489
#
#
# For train set
# The True Positive Rate of trian set for this model 	: 0.9342995169082126
# The False Positive Rate of train set for this model 	: 0.15665399239543726
#
# For test set
# The True Positive Rate of test set for this model 	: 0.9553903345724907
# The False Positive Rate of test set for this model 	: 0.12225705329153605

# %% [markdown]
# *ADULT_MORTALITY*
#
# Train Accuracy: 0.8834, TPR: 0.9343, FPR: 0.1567
#
# Test Accuracy: 0.9133, TPR: 0.9554, FPR: 0.1223
#
# This model (*like the previous one*) performs well on both training and testing sets, with high accuracy scores. (train with 0.8834 and test with 0.9133)
#
# The TPR is high for both datasets, indicating that our model is able to effectively identify cases related to adult mortality. The train set had a value of 0.9343 while the test set had a value of 0.9554 which indicates that model is very likely to classify the data correctly according to the variable - adult mortality.
#
# The train set had a FPR value of 0.1567 and the test set had a FPR value of 0.1223 which is higher than that of the previous feature (*income*). Although the FPR is relatively higher compared to the previous feature (*income*), it is still within an acceptable range. This means that our model is unlikely to falsely classify negative cases as positive at an alarming rate.

# %%
# Split the Dataset into Train and Test
school_train, school_test, lifespan_train, lifespan_test = train_test_split(school, lifespan, test_size = 0.2)

# Create a Decision Tree Classifier object
dectree = DecisionTreeClassifier(max_depth = 3)

# Train the Decision Tree Classifier model
dectree.fit(school_train, lifespan_train)

f = plt.figure(figsize=(12,12))
plot_tree(dectree, filled=True, rounded=True,
          feature_names=["Schooling"],
          class_names=["Low","High"])
# Out:
# [Text(0.5, 0.875, 'Schooling <= 12.075\ngini = 0.492\nsamples = 2350\nvalue = [1320, 1030]\nclass = Low'),
#  Text(0.25, 0.625, 'Schooling <= 10.35\ngini = 0.317\nsamples = 1083\nvalue = [214, 869]\nclass = High'),
#  Text(0.125, 0.375, 'Schooling <= 9.575\ngini = 0.088\nsamples = 610\nvalue = [28, 582]\nclass = High'),
#  Text(0.0625, 0.125, 'gini = 0.022\nsamples = 459\nvalue = [5, 454]\nclass = High'),
#  Text(0.1875, 0.125, 'gini = 0.258\nsamples = 151\nvalue = [23, 128]\nclass = High'),
#  Text(0.375, 0.375, 'Schooling <= 10.675\ngini = 0.477\nsamples = 473\nvalue = [186, 287]\nclass = High'),
#  Text(0.3125, 0.125, 'gini = 0.357\nsamples = 73\nvalue = [17, 56]\nclass = High'),
#  Text(0.4375, 0.125, 'gini = 0.488\nsamples = 400\nvalue = [169, 231]\nclass = High'),
#  Text(0.75, 0.625, 'Schooling <= 15.05\ngini = 0.222\nsamples = 1267\nvalue = [1106, 161]\nclass = Low'),
#  Text(0.625, 0.375, 'Schooling <= 12.55\ngini = 0.307\nsamples = 838\nvalue = [679, 159]\nclass = Low'),
# ...

# %%
# Create a Decision Tree Classifier object
dectree = DecisionTreeClassifier(max_depth = 3)

# Train the Decision Tree Classifier model
dectree.fit(school_test, lifespan_test)

f = plt.figure(figsize=(12,12))
plot_tree(dectree, filled=True, rounded=True,
          feature_names=["Adult_Mortality"],
          class_names=["Low","High"])
# Out:
# [Text(0.5, 0.875, 'Adult_Mortality <= 11.45\ngini = 0.498\nsamples = 588\nvalue = [314, 274]\nclass = Low'),
#  Text(0.25, 0.625, 'Adult_Mortality <= 10.35\ngini = 0.127\nsamples = 220\nvalue = [15, 205]\nclass = High'),
#  Text(0.125, 0.375, 'Adult_Mortality <= 9.075\ngini = 0.024\nsamples = 165\nvalue = [2, 163]\nclass = High'),
#  Text(0.0625, 0.125, 'gini = 0.0\nsamples = 99\nvalue = [0, 99]\nclass = High'),
#  Text(0.1875, 0.125, 'gini = 0.059\nsamples = 66\nvalue = [2, 64]\nclass = High'),
#  Text(0.375, 0.375, 'Adult_Mortality <= 10.55\ngini = 0.361\nsamples = 55\nvalue = [13, 42]\nclass = High'),
#  Text(0.3125, 0.125, 'gini = 0.26\nsamples = 13\nvalue = [2, 11]\nclass = High'),
#  Text(0.4375, 0.125, 'gini = 0.387\nsamples = 42\nvalue = [11, 31]\nclass = High'),
#  Text(0.75, 0.625, 'Adult_Mortality <= 13.05\ngini = 0.305\nsamples = 368\nvalue = [299, 69]\nclass = Low'),
# ...

# %%
# Predict Response corresponding to Predictors
lifespan_train_pred_3 = dectree.predict(school_train)
lifespan_test_pred_3 = dectree.predict(school_test)

# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Classification Accuracy \t:", dectree.score(school_train, lifespan_train))
print()

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Classification Accuracy \t:", dectree.score(school_test, lifespan_test))
print()

# Plot the Confusion Matrix for Train and Test
f, axes = plt.subplots(1, 2, figsize=(12, 4))
cm_train_3 = confusion_matrix(lifespan_train, lifespan_train_pred_3)
sns.heatmap(cm_train_3,
           annot = True, fmt=".0f", annot_kws={"size": 18}, ax = axes[0])
cm_test_3 = confusion_matrix(lifespan_test, lifespan_test_pred_3)
sns.heatmap(cm_test_3,
           annot = True, fmt=".0f", annot_kws={"size": 18}, ax = axes[1])

#Print the TPR and FPR for train set
print ()
FP_tr_3 = cm_train_3[0][1]
FN_tr_3 = cm_train_3[1][0]
TP_tr_3 = cm_train_3[1][1]
TN_tr_3 = cm_train_3[0][0]
print("For train set")
print("The True Positive Rate of trian set for this model \t:", TP_tr_3/(FN_tr_3 + TP_tr_3))
print("The False Positive Rate of train set for this model \t:", FP_tr_3/(TN_tr_3 + FP_tr_3))


#Print the TPR and FPR for test set
print()
FP_tt_3 = cm_test_3[0][1]
FN_tt_3 = cm_test_3[1][0]
TP_tt_3 = cm_test_3[1][1]
TN_tt_3 = cm_test_3[0][0]
print("For test set")
print("The True Positive Rate of test set for this model \t:", TP_tt_3/(FN_tt_3 + TP_tt_3))
print("The False Positive Rate of test set for this model \t:", FP_tt_3/(TN_tt_3 + FP_tt_3))
# Out:
# Goodness of Fit of Model 	Train Dataset
# Classification Accuracy 	: 0.8344680851063829
#
# Goodness of Fit of Model 	Test Dataset
# Classification Accuracy 	: 0.8571428571428571
#
#
# For train set
# The True Positive Rate of trian set for this model 	: 0.7349514563106796
# The False Positive Rate of train set for this model 	: 0.08787878787878788
#
# For test set
# The True Positive Rate of test set for this model 	: 0.7481751824817519
# The False Positive Rate of test set for this model 	: 0.04777070063694268

# %% [markdown]
# *SCHOOLING*
#
# Train Accuracy: 0.8345, TPR: 0.7350, FPR: 0.0879
#
# Test Accuracy: 0.8571, TPR: 0.7482, FPR: 0.0478
#
# The model shows decent performance on both training and testing sets, with moderate to high accuracy scores. (train with 0.8345 and test with 0.8571)
#
# The TPR and FPR values are relatively lower compared to the previous features, indicating that the model's performance in identifying cases related to schooling is not as strong as for the other features (*income and mortality*).
#
# This model had a TPR value of 0.8345 for the train and 0.8571 for the test which is still pretty high.
#
# However, the FPR is notably lower, suggesting that the model has a better ability to avoid falsely classifying negative cases as positive for this feature. This model had a FPR value of 0.0879 and 0.0478 for our train and test data respectively.
#
# ---

# %% [markdown]
# All the train and test models that we used had a depth of 3 as we felt that the train and test accuracy values that we were getting were good enough for our model and purpose.
#
#
# - Generally, in classification tree models, we would want a higher Classification Accuracy and True Positive Rate (TPR), while maintaining a lower False Positive Rate (FPR).
#
# We were able to achieve that result as shown by the values of both the train and test models for all of the classification trees.

# %% [markdown]
# ---
# -
# INCOME_COMPOSITION_OF_RESOURCES:
#
# Train Accuracy: 0.8711, TPR: 0.8344, FPR: 0.0987
#
# Test Accuracy: 0.8878, TPR: 0.8548, FPR: 0.0893
#
# -
# Adult Mortality:
#
# Train Accuracy: 0.8834, TPR: 0.9343, FPR: 0.1567
#
# Test Accuracy: 0.9133, TPR: 0.9554, FPR: 0.1223
#
# -
# Schooling:
#
# Train Accuracy: 0.8345, TPR: 0.7350, FPR: 0.0879
#
# Test Accuracy: 0.8571, TPR: 0.7482, FPR: 0.0478
#
# ---

# %% [markdown]
# The performance of the models varies across different features, with some features showing higher TPR and lower FPR compared to others.
#
# The income composition of resources and adult mortality features exhibit relatively higher TPR values, indicating their importance in predicting the target variable (which is lifespan).
# The schooling feature, although showing lower TPR values, has a lower FPR, suggesting that the model's predictions for negative cases are more reliable.
#
# Overall, our team feels that the income composition of resources is the best variable out of the 3 to be used to predict the lifespan of a person. Although it did not have the highest accuracy or TPR value, the accuracy and TPR value of the model is still relatively high, meaning that it will not have an issue accurately classifying our data for the positive cases. Similarly for the FPR value, the values that our model had was one of the smaller ones, meaning that it will also not struggle when it comes to correctly classifying our negative cases.

# %%
from sklearn.impute import SimpleImputer
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
import pandas as pd
import matplotlib.pyplot as plt

# Correct the feature names to match the dataframe
features = ['SCHOOLING', 'INCOME_COMPOSITION_OF_RESOURCES', 'ADULT_MORTALITY', '_BMI_', 'GDP']
target = 'LIFE_EXPECTANCY_'

# Impute the missing values using the mean for each column (features + target)
#imputer = SimpleImputer(strategy='mean')
#life_expectancy_dt[features] = imputer.fit_transform(life_expectancy_dt[features])
#life_expectancy_dt[target] = imputer.fit_transform(life_expectancy_dt[[target]]).ravel()

# Split the data into training and testing sets
X = life_expectancy_dt[features]
y = life_expectancy_dt[target]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# Initialize the Decision Tree Regressor with a maximum depth of 3
tree_regressor = DecisionTreeRegressor(max_depth=3)

# Train the model on the imputed dataset
tree_regressor.fit(X_train, y_train)

# Plot the decision tree
plt.figure(figsize=(20,10))
plot_tree(tree_regressor, feature_names=features, filled=True, rounded=True, fontsize=12)
plt.show()

# %% [markdown]
# Our team decided to use
